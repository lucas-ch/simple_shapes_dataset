# %%
from simple_shapes_dataset.cli.alignments import create_domain_split
from pathlib import Path

path = Path("/home/lucas/gwsyn/simple_shapes_dataset_biased_00")
da = {frozenset(["v"]): 1.0,
                     frozenset(["color"]): 1.0,
                     frozenset(["action"]): 1.0,
                     frozenset(["attr"]): 1.0,
                     frozenset(["v", "color", "action", "attr"]): 1.0
                     }

create_domain_split(126,
                    path, 
                    [
            ((",".join(sorted(list(domain)))), prop)
            for domain, prop in da.items()
        ],
                     100
                     )
